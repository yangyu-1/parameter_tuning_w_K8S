# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import fetch_california_housing
import pandas as pd
import socket
from itertools import product
import numpy as np

# %%
X,y = fetch_california_housing(return_X_y=True)

# %%
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
model = XGBRegressor()
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': range(1, 11, 1),
        'n_estimators':range(50, 400, 25),
        }
grid_search = GridSearchCV(model, params, scoring="neg_mean_absolute_error", n_jobs=-1, cv=10, verbose=1)

# %%
cap = [dict(zip(params, v)) for v in product(*params.values())]
param_df=pd.DataFrame(cap)

# %%
n =len(test)/10
li = []
for g, df in param_df.groupby(np.arange(len(param_df)) // n):
    print(df.shape)
    print(df.to_json(orient="records"))
# Out:
# (1890, 6)
# ...

# %%
def func(chunk):
    
    param_df=pd.DataFrame([dict(zip(params, v)) for v in product(*params.values())])
    n =len(test)/chunk
    li = []
    for g, df in param_df.groupby(np.arange(len(param_df)) // n):
        shape_1 = df.shape[0]
        param_chunk={}
        for x in df.columns:
            param_chunk[x] = list(df[x].unique())
        li.append(param_chunk)    
    shape_2=0
    for x in li:
        shape_2+=len(pd.DataFrame([dict(zip(x, v)) for v in product(*x.values())]))
    
    print(f"Chunk={chunk},diff = {shape_2-shape_1}")

# %%
for x in np.arange(1,50, 0.1):
    func(x)
# Out:
# Chunk=1.0,diff = 0
# Chunk=1.1,diff = 19702
# Chunk=1.2000000000000002,diff = 19530
# Chunk=1.3000000000000003,diff = 19579
# Chunk=1.4000000000000004,diff = 19800
# Chunk=1.5000000000000004,diff = 12600
# Chunk=1.6000000000000005,diff = 18113
# Chunk=1.7000000000000006,diff = 17418
# Chunk=1.8000000000000007,diff = 16800
# Chunk=1.9000000000000008,diff = 16248
# Chunk=2.000000000000001,diff = 15750
# Chunk=2.100000000000001,diff = 25560
# Chunk=2.200000000000001,diff = 26002
# Chunk=2.300000000000001,diff = 25255
# Chunk=2.4000000000000012,diff = 25830
# Chunk=2.5000000000000013,diff = 25200
# Chunk=2.6000000000000014,diff = 25879
# Chunk=2.7000000000000015,diff = 25340
# Chunk=2.8000000000000016,diff = 26100
# Chunk=2.9000000000000017,diff = 25635
# Chunk=3.0000000000000018,diff = 12600
# Chunk=3.100000000000002,diff = 31731
# Chunk=3.200000000000002,diff = 31579
# Chunk=3.300000000000002,diff = 32302
# Chunk=3.400000000000002,diff = 31797
# Chunk=3.500000000000002,diff = 32580
# ...

# %%
grid_result = grid_search.fit(X, y)
df = pd.DataFrame()
for x in ('mean_test_score','std_test_score','params'): 
    df[x] =grid_result.cv_results_[x]
    
df = pd.concat([df,df.params.apply(pd.Series)],axis=1)
df = df.drop('params',axis=1)
df['hostname'] = socket.gethostname()
